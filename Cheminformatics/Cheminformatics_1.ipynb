# %%
! pip install chembl_webresource_client

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ### Target search for P53 agonist

# %%
target = new_client.target
target_query = target.search('P53')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references                organism  \
# 0   [{'xref_id': 'P04637', 'xref_name': None, 'xre...            Homo sapiens
# 1   [{'xref_id': 'P02340', 'xref_name': None, 'xre...            Mus musculus
# 2                                                  []            Homo sapiens
# 3                                                  []            Homo sapiens
# 4                                                  []            Homo sapiens
# 5                                                  []            Homo sapiens
# 6                                                  []            Homo sapiens
# 7                                                  []            Homo sapiens
# 8                                                  []            Homo sapiens
# 9                                                  []            Homo sapiens
# 10  [{'xref_id': 'O15151', 'xref_name': None, 'xre...            Homo sapiens
# ...

# %%
targets.to_excel('P53 dataset.xlsx', index = False)

# %%
selected_target = targets.target_chembl_id[3]
selected_target
# Out:
# 'CHEMBL1907611'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#      activity_comment  activity_id  \
# 0                None      1424130
# 1                None      1424131
# 2                None      1424132
# 3                None      1424135
# 4                None      1424136
# ...               ...          ...
# 1581             None     24343697
# 1582             None     24343698
# 1583             None     24343699
# 1584             None     24343700
# 1585             None     24343701
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL828042
# 1                                                    []    CHEMBL828042
# 2                                                    []    CHEMBL828042
# 3                                                    []    CHEMBL828042
# 4                                                    []    CHEMBL828042
# ...                                                 ...             ...
# ...

# %%
df.to_csv('P53_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ### Handling missing data

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
#      activity_comment  activity_id  \
# 0                None      1424130
# 1                None      1424131
# 2                None      1424132
# 3                None      1424135
# 4                None      1424136
# ...               ...          ...
# 1581             None     24343697
# 1582             None     24343698
# 1583             None     24343699
# 1584             None     24343700
# 1585             None     24343701
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL828042
# 1                                                    []    CHEMBL828042
# 2                                                    []    CHEMBL828042
# 3                                                    []    CHEMBL828042
# 4                                                    []    CHEMBL828042
# ...                                                 ...             ...
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1295

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id  \
# 0                None      1424130
# 1                None      1424131
# 2                None      1424132
# 3                None      1424135
# 4                None      1424136
# ...               ...          ...
# 1569             None     24343657
# 1570             None     24343658
# 1571             None     24343659
# 1572             None     24343660
# 1573             None     24343661
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL828042
# 1                                                    []    CHEMBL828042
# 2                                                    []    CHEMBL828042
# 3                                                    []    CHEMBL828042
# 4                                                    []    CHEMBL828042
# ...                                                 ...             ...
# ...

# %% [markdown]
# ### Data pre-processing of the bioactivity data

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL179549  CCCN1C(=O)c2ccccc2C1(NC(=O)c1ccc(C(C)(C)C)cc1)...
# 1          CHEMBL360920  CCCN1C(=O)c2ccccc2C1(NC(=O)c1ccccc1)c1ccc(C(C)...
# 2          CHEMBL182052  CCCOC1(c2ccccc2)c2ccccc2C(=O)N1C(Cc1ccc(O)cc1)...
# 3          CHEMBL179662  OCC(NC1(c2ccccc2)c2ccccc2CC1Cc1ccccc1)C(O)c1cc...
# 4          CHEMBL181688  CC(C)(C)c1ccc(COC2(c3ccccc3)c3ccccc3C(=O)N2Cc2...
# ...                 ...                                                ...
# 1569      CHEMBL3649967  CCOC(c1nc2cc(-c3noc(=O)[nH]3)nc(-c3cncc(Cl)c3)...
# 1570      CHEMBL5092438  COCC(C)c1nc2cc(-c3noc(=O)[nH]3)nc(-c3cncc(Cl)c...
# 1571      CHEMBL5089893  CCO[C@@H](c1nc2cc(-c3noc(=O)[nH]3)nc(-c3cncc(C...
# 1572      CHEMBL5085142  Cc1cccc(-c2nc3nc(C(=O)O)nc(NCC4CC4)c3n2CC2CCCC...
# 1573      CHEMBL5084175  C[C@@H](Nc1nc(C(=O)O)nc2nc(-c3ccc4sccc4c3)n(Cc...
#
#      standard_value
# 0           27000.0
# 1           66000.0
# ...

# %%
df3.to_csv('P53_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### Labeling compounds as either being active, inactive or intermediate
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM
# will be considered to be active while those greater than 10,000 nM will be considered to be inactive.
# As for those values in between 1,000 and 10,000 nM will be referred to as intermediate.

# %%
df4 = pd.read_csv('P53_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL179549  CCCN1C(=O)c2ccccc2C1(NC(=O)c1ccc(C(C)(C)C)cc1)...
# 1          CHEMBL360920  CCCN1C(=O)c2ccccc2C1(NC(=O)c1ccccc1)c1ccc(C(C)...
# 2          CHEMBL182052  CCCOC1(c2ccccc2)c2ccccc2C(=O)N1C(Cc1ccc(O)cc1)...
# 3          CHEMBL179662  OCC(NC1(c2ccccc2)c2ccccc2CC1Cc1ccccc1)C(O)c1cc...
# 4          CHEMBL181688  CC(C)(C)c1ccc(COC2(c3ccccc3)c3ccccc3C(=O)N2Cc2...
# ...                 ...                                                ...
# 1290      CHEMBL3649967  CCOC(c1nc2cc(-c3noc(=O)[nH]3)nc(-c3cncc(Cl)c3)...
# 1291      CHEMBL5092438  COCC(C)c1nc2cc(-c3noc(=O)[nH]3)nc(-c3cncc(Cl)c...
# 1292      CHEMBL5089893  CCO[C@@H](c1nc2cc(-c3noc(=O)[nH]3)nc(-c3cncc(C...
# 1293      CHEMBL5085142  Cc1cccc(-c2nc3nc(C(=O)O)nc(NCC4CC4)c3n2CC2CCCC...
# 1294      CHEMBL5084175  C[C@@H](Nc1nc(C(=O)O)nc2nc(-c3ccc4sccc4c3)n(Cc...
#
#       standard_value         class
# ...

# %%
df5.to_csv('P53_03_bioactivity_data_curated.csv', index=False)

# %%
! ls -l
# Out:
# total 2404
# -rw-r--r-- 1 tahi3002 1049089  109082 Apr 16 17:11 P53 agonist dataset.xlsx
# -rw-r--r-- 1 tahi3002 1049089 1979484 Apr 16 17:37 P53_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 tahi3002 1049089  127628 Apr 16 17:41 P53_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 tahi3002 1049089  138027 Apr 16 17:45 P53_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 tahi3002 1049089   96272 Apr 16 17:44 Untitled.ipynb
